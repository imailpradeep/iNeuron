# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv(r"Demographic.csv")
#type(df0) # gives pandas.core.frame.DataFrame

# %%
df0.head(3)
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  ...  Q0060Male Q0060Female     Q1550  \
# 0       World         0    World  ...   580.7496    498.0396  240.3164
# 1       World         0    World  ...   566.7283    490.1993  231.1772
# 2       World         0    World  ...   546.3173    477.2639  218.6745
#
#    Q1550Male  Q1550Female     Q1560  Q1560Male  Q1560Female  NetMigrations  \
# 0   271.6253     208.1916  378.6968   430.2594     324.9308            0.0
# 1   258.0905     203.7797  368.3186   415.8362     319.3364            0.0
# 2   240.0344     197.1422  353.0546   395.5327     309.9103            0.0
#
#    CNMR
# 0   0.0
# 1   0.0
# 2   0.0
#
# [3 rows x 67 columns]

# %%
df0.shape #check the number of rows and columns
# Out:
# (30862, 67)

# %%
df0.info
# Out:
# <bound method DataFrame.info of        SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0              1    900   NaN       NaN       NaN        1.0          1
# 1              1    900   NaN       NaN       NaN        1.0          1
# 2              1    900   NaN       NaN       NaN        1.0          1
# 3              1    900   NaN       NaN       NaN        1.0          1
# 4              1    900   NaN       NaN       NaN        1.0          1
# ...          ...    ...   ...       ...       ...        ...        ...
# 30857        208     44   NaN       BHS        BS       44.0          4
# 30858        208     44   NaN       BHS        BS       44.0          4
# 30859        208     44   NaN       BHS        BS       44.0          4
# 30860        208     44   NaN       BHS        BS       44.0          4
# 30861        208     44   NaN       BHS        BS       44.0          4
#
# ...

# %%
df0.describe
# Out:
# <bound method NDFrame.describe of        SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0              1    900   NaN       NaN       NaN        1.0          1
# 1              1    900   NaN       NaN       NaN        1.0          1
# 2              1    900   NaN       NaN       NaN        1.0          1
# 3              1    900   NaN       NaN       NaN        1.0          1
# 4              1    900   NaN       NaN       NaN        1.0          1
# ...          ...    ...   ...       ...       ...        ...        ...
# 30857        208     44   NaN       BHS        BS       44.0          4
# 30858        208     44   NaN       BHS        BS       44.0          4
# 30859        208     44   NaN       BHS        BS       44.0          4
# 30860        208     44   NaN       BHS        BS       44.0          4
# 30861        208     44   NaN       BHS        BS       44.0          4
#
# ...

# %%
df0.describe()
# Out:
#           SortOrder         LocID     SDMX_code     LocTypeID      ParentID  \
# count  30862.000000  30862.000000  30254.000000  30862.000000  30862.000000
# mean     105.783423    645.282094    416.855689      4.487590   1327.998509
# std       58.991220    639.846886    267.232012      2.215671   1171.227184
# min        1.000000      4.000000      1.000000      1.000000      0.000000
# 25%       55.000000    288.000000    174.000000      4.000000    912.000000
# 50%      106.000000    524.000000    419.000000      4.000000    922.000000
# 75%      157.000000    818.000000    660.000000      4.000000    926.000000
# max      208.000000   5501.000000    914.000000     13.000000   5501.000000
#
#          VarID          Time  TPopulation1Jan  TPopulation1July  \
# count  30862.0  30862.000000     3.086200e+04      3.065900e+04
# mean       2.0   2025.485808     3.339117e+05      3.342195e+05
# std        0.0     43.885926     1.118132e+06      1.118451e+06
# ...

# %%
df0.columns
# Out:
# Index(['SortOrder', 'LocID', 'Notes', 'ISO3_code', 'ISO2_code', 'SDMX_code',
#        'LocTypeID', 'LocTypeName', 'ParentID', 'Location', 'VarID', 'Variant',
#        'Time', 'TPopulation1Jan', 'TPopulation1July', 'TPopulationMale1July',
#        'TPopulationFemale1July', 'PopDensity', 'PopSexRatio', 'MedianAgePop',
#        'NatChange', 'NatChangeRT', 'PopChange', 'PopGrowthRate',
#        'DoublingTime', 'Births', 'Births1519', 'CBR', 'TFR', 'NRR', 'MAC',
#        'SRB', 'Deaths', 'DeathsMale', 'DeathsFemale', 'CDR', 'LEx', 'LExMale',
#        'LExFemale', 'LE15', 'LE15Male', 'LE15Female', 'LE65', 'LE65Male',
#        'LE65Female', 'LE80', 'LE80Male', 'LE80Female', 'InfantDeaths', 'IMR',
#        'LBsurvivingAge1', 'Under5Deaths', 'Q5', 'Q0040', 'Q0040Male',
#        'Q0040Female', 'Q0060', 'Q0060Male', 'Q0060Female', 'Q1550',
#        'Q1550Male', 'Q1550Female', 'Q1560', 'Q1560Male', 'Q1560Female',
#        'NetMigrations', 'CNMR'],
#       dtype='object')

# %%
df0.dtypes # check the type of elements in a column is integer, strings, float
# Out:
# SortOrder          int64
# LocID              int64
# Notes             object
# ISO3_code         object
# ISO2_code         object
#                   ...
# Q1560            float64
# Q1560Male        float64
# Q1560Female      float64
# NetMigrations    float64
# CNMR             float64
# Length: 67, dtype: object

# %%
df0['CNMR'].min()
# Out:
# -526.323

# %%
df0['CNMR'].max()
# Out:
# 415.239

# %%
df0['CNMR'].mean()
# Out:
# 0.6307919955639637

# %%
df0.dtypes=="object"
# Out:
# SortOrder        False
# LocID            False
# Notes             True
# ISO3_code         True
# ISO2_code         True
#                  ...
# Q1560            False
# Q1560Male        False
# Q1560Female      False
# NetMigrations    False
# CNMR             False
# Length: 67, dtype: bool

# %%
a = df0.dtypes[df0.dtypes!="object"]
type(a)
# Out:
# pandas.core.series.Series

# %%
df0.dtypes[df0.dtypes!="object"]
# Out:
# SortOrder          int64
# LocID              int64
# SDMX_code        float64
# LocTypeID          int64
# ParentID           int64
#                   ...
# Q1560            float64
# Q1560Male        float64
# Q1560Female      float64
# NetMigrations    float64
# CNMR             float64
# Length: 61, dtype: object

# %%
df1=df0.select_dtypes(include='object') # df with only objects
df1
# Out:
#       Notes ISO3_code ISO2_code   LocTypeName Location Variant
# 0       NaN       NaN       NaN         World    World  Medium
# 1       NaN       NaN       NaN         World    World  Medium
# 2       NaN       NaN       NaN         World    World  Medium
# 3       NaN       NaN       NaN         World    World  Medium
# 4       NaN       NaN       NaN         World    World  Medium
# ...     ...       ...       ...           ...      ...     ...
# 15089   NaN       JPN        JP  Country/Area    Japan  Medium
# 15090   NaN       JPN        JP  Country/Area    Japan  Medium
# 15091   NaN       JPN        JP  Country/Area    Japan  Medium
# 15092   NaN       JPN        JP  Country/Area    Japan  Medium
# 15093   NaN       JPN        JP  Country/Area    Japan  Medium
#
# [15094 rows x 6 columns]

# %%
df2=df0.select_dtypes(exclude='object') #df without objects
df2
# Out:
#        SortOrder  LocID  SDMX_code  LocTypeID  ParentID  VarID  Time  \
# 0              1    900        1.0          1         0      2  1950
# 1              1    900        1.0          1         0      2  1951
# 2              1    900        1.0          1         0      2  1952
# 3              1    900        1.0          1         0      2  1953
# 4              1    900        1.0          1         0      2  1954
# ...          ...    ...        ...        ...       ...    ...   ...
# 15089        104    392      392.0          4       906      2  1991
# 15090        104    392      392.0          4       906      2  1992
# 15091        104    392      392.0          4       906      2  1993
# 15092        104    392      392.0          4       906      2  1994
# 15093        104    392      392.0          4       906      2  1995
#
#        TPopulation1Jan  TPopulation1July  TPopulationMale1July  ...  \
# 0          2477674.732       2499322.157           1245362.964  ...
# ...

# %%
# dict with key as dtypes and value as list of column names of types
dict0 = df0.columns.to_series().groupby(df0.dtypes).groups 
dict0
#type(dict0) # gives pandas.io.formats.printing.PrettyDict
# Out:
# {int64: ['SortOrder', 'LocID', 'LocTypeID', 'ParentID', 'VarID', 'Time'], float64: ['SDMX_code', 'TPopulation1Jan', 'TPopulation1July', 'TPopulationMale1July', 'TPopulationFemale1July', 'PopDensity', 'PopSexRatio', 'MedianAgePop', 'NatChange', 'NatChangeRT', 'PopChange', 'PopGrowthRate', 'DoublingTime', 'Births', 'Births1519', 'CBR', 'TFR', 'NRR', 'MAC', 'SRB', 'Deaths', 'DeathsMale', 'DeathsFemale', 'CDR', 'LEx', 'LExMale', 'LExFemale', 'LE15', 'LE15Male', 'LE15Female', 'LE65', 'LE65Male', 'LE65Female', 'LE80', 'LE80Male', 'LE80Female', 'InfantDeaths', 'IMR', 'LBsurvivingAge1', 'Under5Deaths', 'Q5', 'Q0040', 'Q0040Male', 'Q0040Female', 'Q0060', 'Q0060Male', 'Q0060Female', 'Q1550', 'Q1550Male', 'Q1550Female', 'Q1560', 'Q1560Male', 'Q1560Female', 'NetMigrations', 'CNMR'], object: ['Notes', 'ISO3_code', 'ISO2_code', 'LocTypeName', 'Location', 'Variant']}

# %%
df0.isnull().sum() # number of null in each column
# Out:
# SortOrder            0
# LocID                0
# Notes            11902
# ISO3_code         4712
# ISO2_code         4864
#                  ...
# Q1560              100
# Q1560Male          100
# Q1560Female        100
# NetMigrations      100
# CNMR               100
# Length: 67, dtype: int64

# %%
df0.isnull().sum().sum() # number of null in dataframe
# Out:
# 30832
